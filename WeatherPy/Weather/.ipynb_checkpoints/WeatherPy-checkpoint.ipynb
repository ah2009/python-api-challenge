# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import urllib
from scipy.stats import linregress
import seaborn as sns

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
#import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
#lat_range = (-90, 90)
#lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
#lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
#lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
#lat_lngs = zip(lats, lngs)
lats = np.random.uniform(low=-90.00, high=90.00, size=1500)
lngs = np.random.uniform(low=-180.00, high=180.00, size=1500)
lat_lngs = zip(lats, lngs)
# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 591

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+weather_api_key
print (url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d

# %%
#List of city data
city_data= []

# %%
# print to logger
print ("Begining Data Retrieval")
print ("------------------")
# Out:
# Begining Data Retrieval
# ------------------

# %%
#create counters 
record_count=1
set_count=1

# %%
#loop through all cities in our list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes 
    if (i % 50==0 and i>=50):
        set_count +=1
        record_count=0
    #create endpoint url with each city
    city_url=url + "&q="+ urllib.request.pathname2url(city)
    #log the url, record and set numbers
    print (f'Processing Record {record_count} of Set {set_count} | {city}')

    print (city_url)    
    #add 1 to the record count
record_count +=1
    #Run an API Request for each of the cities
try:
           #parse json and retrieve data
        city_weather = requests.get(city_url).json()
        
           #Parse out the max temp, humidity, cloudiness, and wind speed
            
        city_lat=city_weather["coord"]["lat"]
        city_lng = city_weather ["coord"]["lng"]
        city_max_temp = city_weather ["main"]["temp_max"]
        city_humidity = city_weather ["main"]["humidity"]
            
        city_clouds = city_weather["clouds"] ["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather ["dt"]
        #Append the city information into city_data
        city_data.append({"City":city,
                             "Lat":city_lat,
                             "LNG":city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity, 
                             "Cloudiness": city_clouds, 
                             "Wind Speed": city_wind,
                             "Coountry":city_country,
                             "Date": city_date})
           
#if an error is experienced skip the city
except: 
    print ("City  not found. Skipping...")
    pass
        
    #Indicate that Data Loading is complete
print ("-------------")
print("Data Retrieval Complete")
print ("--------------")
# Out:
# Processing Record 1 of Set 1 | wenling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=wenling
# Processing Record 1 of Set 1 | los amates
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=los%20amates
# Processing Record 1 of Set 1 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=huarmey
# Processing Record 1 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=vaini
# Processing Record 1 of Set 1 | goure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=goure
# Processing Record 1 of Set 1 | buluang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=buluang
# Processing Record 1 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=atuona
# Processing Record 1 of Set 1 | shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=shimoda
# Processing Record 1 of Set 1 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=hasaki
# Processing Record 1 of Set 1 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ponta%20do%20sol
# Processing Record 1 of Set 1 | inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=inhambane
# Processing Record 1 of Set 1 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=grindavik
# Processing Record 1 of Set 1 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=port%20elizabeth
# Processing Record 1 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=yellowknife
# Processing Record 1 of Set 1 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tautira
# Processing Record 1 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=avarua
# Processing Record 1 of Set 1 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=porto%20novo
# Processing Record 1 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=rikitea
# Processing Record 1 of Set 1 | vuktyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=vuktyl
# Processing Record 1 of Set 1 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=salalah
# Processing Record 1 of Set 1 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=saleaula
# Processing Record 1 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ushuaia
# Processing Record 1 of Set 1 | porbandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=porbandar
# Processing Record 1 of Set 1 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=port%20lincoln
# Processing Record 1 of Set 1 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=beringovskiy
# Processing Record 1 of Set 1 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=provideniya
# Processing Record 1 of Set 1 | padilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=padilla
# Processing Record 1 of Set 1 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=saint-philippe
# Processing Record 1 of Set 1 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ahipara
# Processing Record 1 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=hermanus
# Processing Record 1 of Set 1 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=rawson
# Processing Record 1 of Set 1 | fort saint james
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=fort%20saint%20james
# Processing Record 1 of Set 1 | abonnema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=abonnema
# Processing Record 1 of Set 1 | guymon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=guymon
# Processing Record 1 of Set 1 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=port%20hardy
# Processing Record 1 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=punta%20arenas
# Processing Record 1 of Set 1 | san juan de uraba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=san%20juan%20de%20uraba
# Processing Record 1 of Set 1 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=hervey%20bay
# Processing Record 1 of Set 1 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=sur
# Processing Record 1 of Set 1 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=taolanaro
# Processing Record 1 of Set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tiksi
# Processing Record 1 of Set 1 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=beloha
# Processing Record 1 of Set 1 | krasnoarmeysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=krasnoarmeysk
# Processing Record 1 of Set 1 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=buala
# Processing Record 1 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=hobart
# Processing Record 1 of Set 1 | morwell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=morwell
# Processing Record 1 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=jamestown
# Processing Record 1 of Set 1 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ulladulla
# Processing Record 1 of Set 1 | anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=anloga
# Processing Record 1 of Set 1 | vraca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=vraca
# Processing Record 0 of Set 2 | khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=khasan
# Processing Record 0 of Set 2 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mataura
# Processing Record 0 of Set 2 | waddan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=waddan
# Processing Record 0 of Set 2 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=codrington
# Processing Record 0 of Set 2 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=bethel
# Processing Record 0 of Set 2 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=coihaique
# Processing Record 0 of Set 2 | nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=nome
# Processing Record 0 of Set 2 | morristown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=morristown
# Processing Record 0 of Set 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=arraial%20do%20cabo
# Processing Record 0 of Set 2 | jinchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=jinchang
# Processing Record 0 of Set 2 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mys%20shmidta
# Processing Record 0 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mar%20del%20plata
# Processing Record 0 of Set 2 | rondonopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=rondonopolis
# Processing Record 0 of Set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=barentsburg
# Processing Record 0 of Set 2 | shumskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=shumskiy
# Processing Record 0 of Set 2 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=albany
# Processing Record 0 of Set 2 | kamennomostskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kamennomostskoye
# Processing Record 0 of Set 2 | khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=khandyga
# Processing Record 0 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=port%20alfred
# Processing Record 0 of Set 2 | hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=hamilton
# Processing Record 0 of Set 2 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=puerto%20ayora
# Processing Record 0 of Set 2 | mana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mana
# Processing Record 0 of Set 2 | the valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=the%20valley
# Processing Record 0 of Set 2 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=pisco
# Processing Record 0 of Set 2 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=illoqqortoormiut
# Processing Record 0 of Set 2 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=qaanaaq
# Processing Record 0 of Set 2 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=castro
# Processing Record 0 of Set 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=saskylakh
# Processing Record 0 of Set 2 | santa rosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=santa%20rosa
# Processing Record 0 of Set 2 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=isangel
# Processing Record 0 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kapaa
# Processing Record 0 of Set 2 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=rio%20grande
# Processing Record 0 of Set 2 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=hithadhoo
# Processing Record 0 of Set 2 | warwick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=warwick
# Processing Record 0 of Set 2 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=busselton
# Processing Record 0 of Set 2 | tonekabon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tonekabon
# Processing Record 0 of Set 2 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=airai
# Processing Record 0 of Set 2 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tuktoyaktuk
# Processing Record 0 of Set 2 | qingdao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=qingdao
# Processing Record 0 of Set 2 | qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=qasigiannguit
# Processing Record 0 of Set 2 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=labuhan
# Processing Record 0 of Set 2 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=attawapiskat
# Processing Record 0 of Set 2 | paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=paita
# Processing Record 0 of Set 2 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=palmer
# Processing Record 0 of Set 2 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=sitka
# Processing Record 0 of Set 2 | mpanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mpanda
# Processing Record 0 of Set 2 | mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mabaruma
# Processing Record 0 of Set 2 | hof
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=hof
# Processing Record 0 of Set 2 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=dikson
# Processing Record 0 of Set 2 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tura
# Processing Record 0 of Set 3 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kaitangata
# Processing Record 0 of Set 3 | ibotirama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ibotirama
# Processing Record 0 of Set 3 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=lagoa
# Processing Record 0 of Set 3 | yarmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=yarmouth
# Processing Record 0 of Set 3 | marrakesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=marrakesh
# Processing Record 0 of Set 3 | yashalta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=yashalta
# Processing Record 0 of Set 3 | erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=erenhot
# Processing Record 0 of Set 3 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=iqaluit
# Processing Record 0 of Set 3 | bonfim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=bonfim
# Processing Record 0 of Set 3 | markha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=markha
# Processing Record 0 of Set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kodiak
# Processing Record 0 of Set 3 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=quatre%20cocos
# Processing Record 0 of Set 3 | cedar city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=cedar%20city
# Processing Record 0 of Set 3 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=caravelas
# Processing Record 0 of Set 3 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=bambous%20virieux
# Processing Record 0 of Set 3 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=geraldton
# Processing Record 0 of Set 3 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kavaratti
# Processing Record 0 of Set 3 | ginir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ginir
# Processing Record 0 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=carnarvon
# Processing Record 0 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=upernavik
# Processing Record 0 of Set 3 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=pevek
# Processing Record 0 of Set 3 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=barrow
# Processing Record 0 of Set 3 | moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=moron
# Processing Record 0 of Set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ribeira%20grande
# Processing Record 0 of Set 3 | pasni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=pasni
# Processing Record 0 of Set 3 | rochegda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=rochegda
# Processing Record 0 of Set 3 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=hilo
# Processing Record 0 of Set 3 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=katsuura
# Processing Record 0 of Set 3 | quchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=quchan
# Processing Record 0 of Set 3 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=vostok
# Processing Record 0 of Set 3 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=sinnamary
# Processing Record 0 of Set 3 | qabis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=qabis
# Processing Record 0 of Set 3 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ambon
# Processing Record 0 of Set 3 | katobu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=katobu
# Processing Record 0 of Set 3 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=belushya%20guba
# Processing Record 0 of Set 3 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=belyy%20yar
# Processing Record 0 of Set 3 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mitsamiouli
# Processing Record 0 of Set 3 | lakes entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=lakes%20entrance
# Processing Record 0 of Set 3 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=narsaq
# Processing Record 0 of Set 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=longyearbyen
# Processing Record 0 of Set 3 | calabar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=calabar
# Processing Record 0 of Set 3 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=georgetown
# Processing Record 0 of Set 3 | ca mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ca%20mau
# Processing Record 0 of Set 3 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=paamiut
# Processing Record 0 of Set 3 | reconquista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=reconquista
# Processing Record 0 of Set 3 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=yulara
# Processing Record 0 of Set 3 | tocache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tocache
# Processing Record 0 of Set 3 | madoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=madoc
# Processing Record 0 of Set 3 | warqla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=warqla
# Processing Record 0 of Set 3 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=cockburn%20town
# Processing Record 0 of Set 4 | gourdon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=gourdon
# Processing Record 0 of Set 4 | pozoblanco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=pozoblanco
# Processing Record 0 of Set 4 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=east%20london
# Processing Record 0 of Set 4 | kerteh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kerteh
# Processing Record 0 of Set 4 | bhatkal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=bhatkal
# Processing Record 0 of Set 4 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=shingu
# Processing Record 0 of Set 4 | dryden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=dryden
# Processing Record 0 of Set 4 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tasiilaq
# Processing Record 0 of Set 4 | hirado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=hirado
# Processing Record 0 of Set 4 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=komsomolskiy
# Processing Record 0 of Set 4 | la orilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=la%20orilla
# Processing Record 0 of Set 4 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=flinders
# Processing Record 0 of Set 4 | igrim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=igrim
# Processing Record 0 of Set 4 | gondar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=gondar
# Processing Record 0 of Set 4 | muzaffargarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=muzaffargarh
# Processing Record 0 of Set 4 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=torbay
# Processing Record 0 of Set 4 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=honiara
# Processing Record 0 of Set 4 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=sobolevo
# Processing Record 0 of Set 4 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=makakilo%20city
# Processing Record 0 of Set 4 | bairiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=bairiki
# Processing Record 0 of Set 4 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=nanortalik
# Processing Record 0 of Set 4 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=jalu
# Processing Record 0 of Set 4 | kleck
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kleck
# Processing Record 0 of Set 4 | opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=opuwo
# Processing Record 0 of Set 4 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=severo-kurilsk
# Processing Record 0 of Set 4 | tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tromso
# Processing Record 0 of Set 4 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=khatanga
# Processing Record 0 of Set 4 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=nikolskoye
# Processing Record 0 of Set 4 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=halalo
# Processing Record 0 of Set 4 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=necochea
# Processing Record 0 of Set 4 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=alta%20floresta
# Processing Record 0 of Set 4 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=bengkulu
# Processing Record 0 of Set 4 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=saint-augustin
# Processing Record 0 of Set 4 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=richards%20bay
# Processing Record 0 of Set 4 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=thompson
# Processing Record 0 of Set 4 | toora-khem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=toora-khem
# Processing Record 0 of Set 4 | longkou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=longkou
# Processing Record 0 of Set 4 | lakhipur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=lakhipur
# Processing Record 0 of Set 4 | saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=saint%20anthony
# Processing Record 0 of Set 4 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=amderma
# Processing Record 0 of Set 4 | northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=northam
# Processing Record 0 of Set 4 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ilulissat
# Processing Record 0 of Set 4 | rio cuarto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=rio%20cuarto
# Processing Record 0 of Set 4 | yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=yenagoa
# Processing Record 0 of Set 4 | torrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=torrington
# Processing Record 0 of Set 4 | kropotkin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kropotkin
# Processing Record 0 of Set 4 | borovoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=borovoy
# Processing Record 0 of Set 4 | ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ulaangom
# Processing Record 0 of Set 4 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=cape%20town
# Processing Record 0 of Set 4 | tsumeb
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tsumeb
# Processing Record 0 of Set 5 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=butaritari
# Processing Record 0 of Set 5 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=bredasdorp
# Processing Record 0 of Set 5 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=nantucket
# Processing Record 0 of Set 5 | shahrud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=shahrud
# Processing Record 0 of Set 5 | antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=antalaha
# Processing Record 0 of Set 5 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=san%20cristobal
# Processing Record 0 of Set 5 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=victoria
# Processing Record 0 of Set 5 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mount%20isa
# Processing Record 0 of Set 5 | hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=hualmay
# Processing Record 0 of Set 5 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=egvekinot
# Processing Record 0 of Set 5 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tumannyy
# Processing Record 0 of Set 5 | taipu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=taipu
# Processing Record 0 of Set 5 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=cidreira
# Processing Record 0 of Set 5 | indianola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=indianola
# Processing Record 0 of Set 5 | kasimov
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kasimov
# Processing Record 0 of Set 5 | rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=rundu
# Processing Record 0 of Set 5 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=zyryanka
# Processing Record 0 of Set 5 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=yerbogachen
# Processing Record 0 of Set 5 | la asuncion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=la%20asuncion
# Processing Record 0 of Set 5 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tessalit
# Processing Record 0 of Set 5 | gavrilov posad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=gavrilov%20posad
# Processing Record 0 of Set 5 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=san%20quintin
# Processing Record 0 of Set 5 | alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=alice%20springs
# Processing Record 0 of Set 5 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=klaksvik
# Processing Record 0 of Set 5 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tsihombe
# Processing Record 0 of Set 5 | mercedes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mercedes
# Processing Record 0 of Set 5 | wasilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=wasilla
# Processing Record 0 of Set 5 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=margate
# Processing Record 0 of Set 5 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ancud
# Processing Record 0 of Set 5 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=bluff
# Processing Record 0 of Set 5 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=san%20patricio
# Processing Record 0 of Set 5 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=vardo
# Processing Record 0 of Set 5 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=alofi
# Processing Record 0 of Set 5 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=nizhneyansk
# Processing Record 0 of Set 5 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=thinadhoo
# Processing Record 0 of Set 5 | morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=morondava
# Processing Record 0 of Set 5 | nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=nizwa
# Processing Record 0 of Set 5 | barentu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=barentu
# Processing Record 0 of Set 5 | khor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=khor
# Processing Record 0 of Set 5 | sri aman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=sri%20aman
# Processing Record 0 of Set 5 | devils lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=devils%20lake
# Processing Record 0 of Set 5 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=fort%20nelson
# Processing Record 0 of Set 5 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=cherskiy
# Processing Record 0 of Set 5 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kamenskoye
# Processing Record 0 of Set 5 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=bandarbeyla
# Processing Record 0 of Set 5 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=meulaboh
# Processing Record 0 of Set 5 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=esperance
# Processing Record 0 of Set 5 | fort portal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=fort%20portal
# Processing Record 0 of Set 5 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=sao%20filipe
# Processing Record 0 of Set 5 | luwuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=luwuk
# Processing Record 0 of Set 6 | jining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=jining
# Processing Record 0 of Set 6 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=talnakh
# Processing Record 0 of Set 6 | uvira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=uvira
# Processing Record 0 of Set 6 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=chuy
# Processing Record 0 of Set 6 | hrodna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=hrodna
# Processing Record 0 of Set 6 | agropoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=agropoli
# Processing Record 0 of Set 6 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=umm%20kaddadah
# Processing Record 0 of Set 6 | magaria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=magaria
# Processing Record 0 of Set 6 | port keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=port%20keats
# Processing Record 0 of Set 6 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=vila%20franca%20do%20campo
# Processing Record 0 of Set 6 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=grand%20river%20south%20east
# Processing Record 0 of Set 6 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=chokurdakh
# Processing Record 0 of Set 6 | potiskum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=potiskum
# Processing Record 0 of Set 6 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=grand%20gaube
# Processing Record 0 of Set 6 | sidmouth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=sidmouth
# Processing Record 0 of Set 6 | cruzeiro do sul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=cruzeiro%20do%20sul
# Processing Record 0 of Set 6 | starkville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=starkville
# Processing Record 0 of Set 6 | shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=shache
# Processing Record 0 of Set 6 | khawhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=khawhai
# Processing Record 0 of Set 6 | moranbah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=moranbah
# Processing Record 0 of Set 6 | merano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=merano
# Processing Record 0 of Set 6 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=riyadh
# Processing Record 0 of Set 6 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=eureka
# Processing Record 0 of Set 6 | mahenge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mahenge
# Processing Record 0 of Set 6 | palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=palabuhanratu
# Processing Record 0 of Set 6 | zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=zhangye
# Processing Record 0 of Set 6 | gillette
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=gillette
# Processing Record 0 of Set 6 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=lasa
# Processing Record 0 of Set 6 | campbell river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=campbell%20river
# Processing Record 0 of Set 6 | tahta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tahta
# Processing Record 0 of Set 6 | sorada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=sorada
# Processing Record 0 of Set 6 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kruisfontein
# Processing Record 0 of Set 6 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mahebourg
# Processing Record 0 of Set 6 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=westport
# Processing Record 0 of Set 6 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=acapulco
# Processing Record 0 of Set 6 | penticton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=penticton
# Processing Record 0 of Set 6 | taonan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=taonan
# Processing Record 0 of Set 6 | carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=carutapera
# Processing Record 0 of Set 6 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=saint%20george
# Processing Record 0 of Set 6 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=marcona
# Processing Record 0 of Set 6 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=camacha
# Processing Record 0 of Set 6 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=luderitz
# Processing Record 0 of Set 6 | kitob
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kitob
# Processing Record 0 of Set 6 | notre-dame-du-lac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=notre-dame-du-lac
# Processing Record 0 of Set 6 | mangrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mangrol
# Processing Record 0 of Set 6 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=karratha
# Processing Record 0 of Set 6 | kumbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kumbo
# Processing Record 0 of Set 6 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=gat
# Processing Record 0 of Set 6 | duiwelskloof
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=duiwelskloof
# Processing Record 0 of Set 6 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=lebu
# Processing Record 0 of Set 7 | san bernardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=san%20bernardo
# Processing Record 0 of Set 7 | gondanglegi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=gondanglegi
# Processing Record 0 of Set 7 | torbat-e jam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=torbat-e%20jam
# Processing Record 0 of Set 7 | kenora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kenora
# Processing Record 0 of Set 7 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=marsh%20harbour
# Processing Record 0 of Set 7 | fallon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=fallon
# Processing Record 0 of Set 7 | nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=nhulunbuy
# Processing Record 0 of Set 7 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=touros
# Processing Record 0 of Set 7 | zimapan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=zimapan
# Processing Record 0 of Set 7 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=faanui
# Processing Record 0 of Set 7 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=portland
# Processing Record 0 of Set 7 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=rio%20gallegos
# Processing Record 0 of Set 7 | dakoro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=dakoro
# ...
# Processing Record 0 of Set 10 | qui nhon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=qui%20nhon
# Processing Record 0 of Set 10 | mayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mayenne
# Processing Record 0 of Set 10 | barbar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=barbar
# Processing Record 0 of Set 10 | manavalakurichi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=manavalakurichi
# Processing Record 0 of Set 10 | kidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kidal
# Processing Record 0 of Set 10 | krasnyy chikoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=krasnyy%20chikoy
# Processing Record 0 of Set 10 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=sorland
# Processing Record 0 of Set 10 | kampong thum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kampong%20thum
# Processing Record 0 of Set 10 | karacabey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=karacabey
# Processing Record 0 of Set 10 | smiths falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=smiths%20falls
# Processing Record 0 of Set 10 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=naze
# Processing Record 0 of Set 10 | stepnyak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=stepnyak
# Processing Record 0 of Set 11 | laramie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=laramie
# Processing Record 0 of Set 11 | markova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=markova
# Processing Record 0 of Set 11 | suba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=suba
# Processing Record 0 of Set 11 | kuche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kuche
# Processing Record 0 of Set 11 | cusuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=cusuna
# Processing Record 0 of Set 11 | lolua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=lolua
# Processing Record 0 of Set 11 | shenjiamen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=shenjiamen
# Processing Record 0 of Set 11 | moyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=moyo
# Processing Record 0 of Set 11 | champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=champerico
# Processing Record 0 of Set 11 | maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=maceio
# Processing Record 0 of Set 11 | merauke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=merauke
# Processing Record 0 of Set 11 | toliary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=toliary
# Processing Record 0 of Set 11 | uto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=uto
# Processing Record 0 of Set 11 | urucara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=urucara
# Processing Record 0 of Set 11 | leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=leh
# Processing Record 0 of Set 11 | cosala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=cosala
# Processing Record 0 of Set 11 | marathon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=marathon
# Processing Record 0 of Set 11 | iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=iracoubo
# Processing Record 0 of Set 11 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=umzimvubu
# Processing Record 0 of Set 11 | geresk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=geresk
# Processing Record 0 of Set 11 | guadalupe victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=guadalupe%20victoria
# Processing Record 0 of Set 11 | lockhart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=lockhart
# Processing Record 0 of Set 11 | riviere-au-renard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=riviere-au-renard
# Processing Record 0 of Set 11 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=sentyabrskiy
# Processing Record 0 of Set 11 | roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=roebourne
# Processing Record 0 of Set 11 | aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=aksu
# Processing Record 0 of Set 11 | bosaso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=bosaso
# Processing Record 0 of Set 11 | high level
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=high%20level
# Processing Record 0 of Set 11 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=havre-saint-pierre
# Processing Record 0 of Set 11 | nelidovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=nelidovo
# Processing Record 0 of Set 11 | panama city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=panama%20city
# Processing Record 0 of Set 11 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=comodoro%20rivadavia
# Processing Record 0 of Set 11 | atikokan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=atikokan
# Processing Record 0 of Set 11 | porto velho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=porto%20velho
# Processing Record 0 of Set 11 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=saldanha
# Processing Record 0 of Set 11 | hundested
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=hundested
# Processing Record 0 of Set 11 | tullamore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tullamore
# Processing Record 0 of Set 11 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=lata
# Processing Record 0 of Set 11 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kloulklubed
# Processing Record 0 of Set 11 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=port-gentil
# Processing Record 0 of Set 11 | druskininkai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=druskininkai
# Processing Record 0 of Set 11 | mahadday weyne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mahadday%20weyne
# Processing Record 0 of Set 11 | sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=sibolga
# Processing Record 0 of Set 11 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=udachnyy
# Processing Record 0 of Set 11 | sennoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=sennoy
# Processing Record 0 of Set 11 | kapoeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kapoeta
# Processing Record 0 of Set 11 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=coquimbo
# Processing Record 0 of Set 11 | mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mecca
# Processing Record 0 of Set 11 | gunjur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=gunjur
# Processing Record 0 of Set 11 | muroto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=muroto
# Processing Record 0 of Set 12 | oriximina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=oriximina
# Processing Record 0 of Set 12 | ghanzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ghanzi
# Processing Record 0 of Set 12 | pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=pierre
# Processing Record 0 of Set 12 | urucui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=urucui
# Processing Record 0 of Set 12 | utiroa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=utiroa
# Processing Record 0 of Set 12 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mehamn
# Processing Record 0 of Set 12 | kaputa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=kaputa
# Processing Record 0 of Set 12 | afanasyevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=afanasyevo
# Processing Record 0 of Set 12 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=banda%20aceh
# Processing Record 0 of Set 12 | chimbote
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=chimbote
# Processing Record 0 of Set 12 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=aykhal
# Processing Record 0 of Set 12 | ibia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ibia
# Processing Record 0 of Set 12 | buenos aires
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=buenos%20aires
# Processing Record 0 of Set 12 | maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=maragogi
# Processing Record 0 of Set 12 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=salinopolis
# Processing Record 0 of Set 12 | whitianga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=whitianga
# Processing Record 0 of Set 12 | gardez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=gardez
# Processing Record 0 of Set 12 | la peca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=la%20peca
# Processing Record 0 of Set 12 | arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=arman
# Processing Record 0 of Set 12 | dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=dauphin
# Processing Record 0 of Set 12 | teguise
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=teguise
# Processing Record 0 of Set 12 | remanso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=remanso
# Processing Record 0 of Set 12 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=pacific%20grove
# Processing Record 0 of Set 12 | rameshki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=rameshki
# Processing Record 0 of Set 12 | pachino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=pachino
# Processing Record 0 of Set 12 | orlik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=orlik
# Processing Record 0 of Set 12 | bayji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=bayji
# Processing Record 0 of Set 12 | sompeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=sompeta
# Processing Record 0 of Set 12 | ciudad guayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=ciudad%20guayana
# Processing Record 0 of Set 12 | andijon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=andijon
# Processing Record 0 of Set 12 | pingliang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=pingliang
# Processing Record 0 of Set 12 | mikuni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=mikuni
# Processing Record 0 of Set 12 | imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=imbituba
# Processing Record 0 of Set 12 | tutora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=tutora
# Processing Record 0 of Set 12 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=flin%20flon
# Processing Record 0 of Set 12 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=broome
# Processing Record 0 of Set 12 | bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=bonthe
# Processing Record 0 of Set 12 | yankton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=yankton
# Processing Record 0 of Set 12 | gurskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=gurskoye
# Processing Record 0 of Set 12 | nebolchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=nebolchi
# Processing Record 0 of Set 12 | zambezi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=44f8e8862af70198e70475025689c73d&q=zambezi
# City  not found. Skipping...
# -------------
# Data Retrieval Complete
# --------------

# %%
 #cities = ["?"]

# set up lists to hold reponse info
#lat = []
#temp = []

# Loop through the list of cities and perform a request for data on each
#for city in cities:
   # response = requests.get(query_url + city).json()
   # lat.append(response['coord']['lat'])
   # temp.append(response['main']['temp'])

#print(f"The latitude information received is: {lat}")
#print(f"The temperature information received is: {temp}")

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#convert array of JSONs into Pandas DataFrame
city_data_pd=pd.DataFrame(city_data)
city_data_pd.head()
#"col" :["row1", "row2"
#city_data
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#Extract relevant fields from the DataFrame
lats=city_data_pd["Lat"]
max_temps=city_data_pd ["Max Temp"]
humidity=city_data_pd ["Humidity"]
cloudiness=city_data_pd ["Cloudiness"]
wind_speed=city_data_pd["Wind Speed"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lat'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-00ab9e746f4f> in <module>
#       1 #Extract relevant fields from the DataFrame
# ----> 2 lats=city_data_pd["lat"]
#       3 max_temps=city_data_pd ["Max Temp"]
#       4 humidity=city_data_pd ["Humidity"]
#       5 cloudiness=city_data_pd ["Cloudiness"]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'lat'

# %%
#Export city_data into a csv file
city_data_pd.to_csv(output_data_file, index_label="City_Id")

# %%
#Show record count
city_data_pd.count()

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Build scatter plot 
plt.scatter(lats, max_temps, 
           edgecolors="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")
plt.title(f'City Latitude vs Max Temperature ({time.strftime(%x)})')
plt.xlabel ("Latitude")
plt.ylable("Max Temerature (F)")
plt.grid (True)
#save
plt.savefig ("output_data/Fig1.png")
#show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Build scatter plot 
plt.scatter(lats, humidity, 
           edgecolors="black", linewidth=1, marker="o",
           alpha=0.8, label="Cities")
plt.title(f'City Latitude vs Humidity ({time.strftime(%x)})')
plt.xlabel ("Latitude")
plt.ylable("Humidity (%)")
plt.grid (True)
#save
plt.savefig ("output_data/Fig2.png")
#show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
